# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
df = pd.read_csv('../data/session_1/TEMP_session_1_synced.csv', index_col=0)
session_start = df.loc[np.all(df > 28, axis=1), ].index[0]

# %%
choir_start = 1529577286

# %%
df = pd.read_csv('../data/session_1/HR_session_1_synced.csv', index_col=0)
df = df[(df.index > session_start) & (df.index < choir_start)]

# %%
df = df - df.mean()
df.plot(legend=False)

# %%
from sklearn.datasets import make_blobs

# %%
    center_box = (100, 200) # defines the box that cluster centres are allowed to be in
    standard_dev = 15 # defines the standard deviation of clusters
    X, y = make_blobs(n_samples=200, n_features=2, center_box=center_box, cluster_std=standard_dev)

    fig, ax = plt.subplots()
    ax.scatter(X[:, 0], X[:, 1], c=y)

# %%
fig.savefig('/home/nfirth/Desktop/tmp.png')

# %%
from sklearn import linear_model
from pandas import DataFrame 

x1 = [[1,2],[2,3],[3,4]]
x2 = [[1,1],[3,2],[3,5]]
y = [[1,0],[1,2],[2,3]]
model = {
    'vec1': x1,
    'vec2': x2,
    'compound_vec': y}

df = DataFrame(model, columns=['vec1','vec2','compound_vec'])
x = df[['vec1','vec2']].astype(object)
y = df['compound_vec'].astype(object)
# regr = linear_model.LinearRegression()
# regr.fit(x,y)

# %%
# Out:
# 0    [1, 0]
# 1    [1, 2]
# 2    [2, 3]
# Name: compound_vec, dtype: object
